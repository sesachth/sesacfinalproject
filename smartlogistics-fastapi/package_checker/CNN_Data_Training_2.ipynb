# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from pathlib import Path

# %%
# ✅ 데이터 로딩
base_path = Path('C:/labs_python/Sesacfinalproject/output_image')
x_train_rgb = np.load(base_path / 'x_train_rgb_balanced.npy')
x_test_rgb = np.load(base_path / 'x_test_rgb_balanced.npy')
y_train = np.load(base_path / 'y_train_balanced.npy')
y_test = np.load(base_path / 'y_test_balanced.npy')

# %%
# ✅ 데이터 증강 (최적화)
datagen_rgb = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)
datagen_rgb.fit(x_train_rgb)

# %%
# ✅ 전이 학습 설정 (상위 레이어 Fine-Tuning 활성화)
base_model = MobileNetV2(input_shape=(112, 112, 3), include_top=False, weights='imagenet')
base_model.trainable = True
# Out:
# C:\Users\kenek\AppData\Local\Temp\ipykernel_20028\3363080828.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(input_shape=(112, 112, 3), include_top=False, weights='imagenet')

# %%
# ✅ 모델 구성 (Dropout과 BatchNormalization)
model_rgb = models.Sequential([
    base_model,
    layers.Conv2D(128, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.7),
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.7),
    layers.Dense(1, activation='sigmoid')
])

# %%
# ✅ 모델 컴파일 (학습률 증가)
model_rgb.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# %%
# ✅ 조기 종료 콜백 (조기 종료 기준을 val_loss에서 val_accuracy로 변경)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# ✅ 모델 훈련
history_rgb = model_rgb.fit(
    datagen_rgb.flow(x_train_rgb, y_train, batch_size=16),
    validation_data=(x_test_rgb, y_test),
    epochs=50,
    callbacks=[early_stopping]
)


# ✅ 학습 정확도 시각화
plt.figure(figsize=(10,7))
plt.plot(history_rgb.history['accuracy'], label='Training Accuracy')
plt.plot(history_rgb.history['val_accuracy'], label='Validation Accuracy')
plt.title('CNN Training Accuracy (RGB Only - Fine-Tuned and Optimized)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# c:\labs_python\.venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 39s 169ms/step - accuracy: 0.5339 - loss: 0.9086 - val_accuracy: 0.6739 - val_loss: 0.6120
# Epoch 2/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.5750 - loss: 0.8273 - val_accuracy: 0.6919 - val_loss: 0.5746
# Epoch 3/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 24s 170ms/step - accuracy: 0.5827 - loss: 0.7735 - val_accuracy: 0.7261 - val_loss: 0.5535
# Epoch 4/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 192ms/step - accuracy: 0.6416 - loss: 0.7155 - val_accuracy: 0.7333 - val_loss: 0.5349
# Epoch 5/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 192ms/step - accuracy: 0.6612 - loss: 0.6731 - val_accuracy: 0.7387 - val_loss: 0.5179
# Epoch 6/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 194ms/step - accuracy: 0.6610 - loss: 0.6743 - val_accuracy: 0.7333 - val_loss: 0.5173
# Epoch 7/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 197ms/step - accuracy: 0.7050 - loss: 0.6129 - val_accuracy: 0.7423 - val_loss: 0.5048
# Epoch 8/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 194ms/step - accuracy: 0.6909 - loss: 0.6178 - val_accuracy: 0.7604 - val_loss: 0.4817
# Epoch 9/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 26s 187ms/step - accuracy: 0.7217 - loss: 0.5681 - val_accuracy: 0.7676 - val_loss: 0.4785
# Epoch 10/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 26s 189ms/step - accuracy: 0.7295 - loss: 0.5585 - val_accuracy: 0.7766 - val_loss: 0.4631
# Epoch 11/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 197ms/step - accuracy: 0.7432 - loss: 0.5716 - val_accuracy: 0.7874 - val_loss: 0.4498
# Epoch 12/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 26s 187ms/step - accuracy: 0.7467 - loss: 0.5216 - val_accuracy: 0.7910 - val_loss: 0.4439
# Epoch 13/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 25s 180ms/step - accuracy: 0.7373 - loss: 0.5355 - val_accuracy: 0.8018 - val_loss: 0.4297
# Epoch 14/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 25s 178ms/step - accuracy: 0.7878 - loss: 0.4547 - val_accuracy: 0.8054 - val_loss: 0.4040
# Epoch 15/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 25s 179ms/step - accuracy: 0.7624 - loss: 0.5222 - val_accuracy: 0.8108 - val_loss: 0.3955
# Epoch 16/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 25s 179ms/step - accuracy: 0.8044 - loss: 0.4547 - val_accuracy: 0.8180 - val_loss: 0.3888
# Epoch 17/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.7892 - loss: 0.4490 - val_accuracy: 0.8288 - val_loss: 0.3839
# Epoch 18/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.7999 - loss: 0.4475 - val_accuracy: 0.8324 - val_loss: 0.3763
# Epoch 19/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 25s 181ms/step - accuracy: 0.7992 - loss: 0.4560 - val_accuracy: 0.8216 - val_loss: 0.3773
# Epoch 20/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 25s 179ms/step - accuracy: 0.8107 - loss: 0.4541 - val_accuracy: 0.8198 - val_loss: 0.3699
# Epoch 21/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 25s 180ms/step - accuracy: 0.7946 - loss: 0.4478 - val_accuracy: 0.8180 - val_loss: 0.3617
# Epoch 22/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 192ms/step - accuracy: 0.7867 - loss: 0.4696 - val_accuracy: 0.8270 - val_loss: 0.3622
# Epoch 23/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 194ms/step - accuracy: 0.8115 - loss: 0.4325 - val_accuracy: 0.8288 - val_loss: 0.3566
# Epoch 24/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 195ms/step - accuracy: 0.7884 - loss: 0.4573 - val_accuracy: 0.8378 - val_loss: 0.3582
# Epoch 25/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 192ms/step - accuracy: 0.8002 - loss: 0.4298 - val_accuracy: 0.8270 - val_loss: 0.3556
# Epoch 26/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 29s 205ms/step - accuracy: 0.8290 - loss: 0.3939 - val_accuracy: 0.8288 - val_loss: 0.3529
# Epoch 27/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 29s 205ms/step - accuracy: 0.8481 - loss: 0.3792 - val_accuracy: 0.8342 - val_loss: 0.3615
# Epoch 28/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 29s 207ms/step - accuracy: 0.8390 - loss: 0.3868 - val_accuracy: 0.8396 - val_loss: 0.3639
# Epoch 29/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 198ms/step - accuracy: 0.8237 - loss: 0.4037 - val_accuracy: 0.8450 - val_loss: 0.3639
# Epoch 30/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 203ms/step - accuracy: 0.8223 - loss: 0.4228 - val_accuracy: 0.8486 - val_loss: 0.3593
# Epoch 31/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 202ms/step - accuracy: 0.8480 - loss: 0.3603 - val_accuracy: 0.8505 - val_loss: 0.3581
# Epoch 32/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 201ms/step - accuracy: 0.8444 - loss: 0.3743 - val_accuracy: 0.8559 - val_loss: 0.3555
# Epoch 33/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 203ms/step - accuracy: 0.8475 - loss: 0.3705 - val_accuracy: 0.8541 - val_loss: 0.3532
# Epoch 34/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 29s 211ms/step - accuracy: 0.8484 - loss: 0.3812 - val_accuracy: 0.8559 - val_loss: 0.3527
# Epoch 35/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 204ms/step - accuracy: 0.8518 - loss: 0.3428 - val_accuracy: 0.8595 - val_loss: 0.3520
# Epoch 36/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 27s 197ms/step - accuracy: 0.8622 - loss: 0.3205 - val_accuracy: 0.8559 - val_loss: 0.3513
# Epoch 37/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 199ms/step - accuracy: 0.8564 - loss: 0.3339 - val_accuracy: 0.8613 - val_loss: 0.3496
# Epoch 38/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 32s 231ms/step - accuracy: 0.8478 - loss: 0.3615 - val_accuracy: 0.8685 - val_loss: 0.3515
# Epoch 39/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 30s 214ms/step - accuracy: 0.8370 - loss: 0.3637 - val_accuracy: 0.8667 - val_loss: 0.3469
# Epoch 40/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 202ms/step - accuracy: 0.8620 - loss: 0.3328 - val_accuracy: 0.8685 - val_loss: 0.3440
# Epoch 41/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 202ms/step - accuracy: 0.8661 - loss: 0.3147 - val_accuracy: 0.8667 - val_loss: 0.3377
# Epoch 42/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 201ms/step - accuracy: 0.8679 - loss: 0.3202 - val_accuracy: 0.8685 - val_loss: 0.3414
# Epoch 43/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 29s 209ms/step - accuracy: 0.8727 - loss: 0.2879 - val_accuracy: 0.8703 - val_loss: 0.3430
# Epoch 44/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 29s 205ms/step - accuracy: 0.8718 - loss: 0.3254 - val_accuracy: 0.8667 - val_loss: 0.3380
# Epoch 45/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 204ms/step - accuracy: 0.8613 - loss: 0.3234 - val_accuracy: 0.8649 - val_loss: 0.3460
# Epoch 46/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 204ms/step - accuracy: 0.8669 - loss: 0.3225 - val_accuracy: 0.8613 - val_loss: 0.3508
# Epoch 47/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 28s 203ms/step - accuracy: 0.8849 - loss: 0.2638 - val_accuracy: 0.8739 - val_loss: 0.3478
# Epoch 48/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 31s 225ms/step - accuracy: 0.8947 - loss: 0.2639 - val_accuracy: 0.8667 - val_loss: 0.3395
# Epoch 49/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 30s 216ms/step - accuracy: 0.8901 - loss: 0.3013 - val_accuracy: 0.8595 - val_loss: 0.3363
# Epoch 50/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 29s 206ms/step - accuracy: 0.8735 - loss: 0.2931 - val_accuracy: 0.8649 - val_loss: 0.3378

# %%
#model_rgb.save(base_path / 'trained_model_best0.h5')

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input
import matplotlib.pyplot as plt

# ✅ 모델 재구성 (명시적 입력 추가)
input_layer = Input(shape=(112, 112, 3))
base_model = MobileNetV2(input_shape=(112, 112, 3), include_top=False, weights='imagenet')
base_model.trainable = True

# ✅ Dropout과 BatchNormalization 포함
x = base_model(input_layer)
x = layers.Conv2D(128, (3,3), activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.7)(x)
x = layers.GlobalAveragePooling2D(name="global_average_pooling2d")(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.7)(x)
output_layer = layers.Dense(1, activation='sigmoid')(x)

# ✅ 모델 구성
model_rgb = models.Model(inputs=input_layer, outputs=output_layer)

# ✅ 모델에 데이터 한번 통과시켜 build 완료
model_rgb.compile(optimizer='adam', loss='binary_crossentropy')
model_rgb.predict(np.random.rand(1, 112, 112, 3))

# ✅ GlobalAveragePooling2D 레이어만을 추출하는 모델
intermediate_model = models.Model(inputs=model_rgb.input,
                                  outputs=model_rgb.get_layer('global_average_pooling2d').output)

# ✅ 예제 데이터로 예측 수행
sample_image = x_train_rgb[0:1]  # 첫 번째 이미지 사용
feature_map = intermediate_model.predict(sample_image)

# ✅ GlobalAveragePooling2D의 출력을 시각화
plt.figure(figsize=(10, 6))
plt.bar(range(len(feature_map[0])), feature_map[0])
plt.title('Global Average Pooled Output')
plt.xlabel('Feature Index')
plt.ylabel('Value')
plt.show()
# Out:
# C:\Users\kenek\AppData\Local\Temp\ipykernel_20028\3404200223.py:7: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(input_shape=(112, 112, 3), include_top=False, weights='imagenet')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step

# %%
import matplotlib.pyplot as plt
from tensorflow.keras import models, layers, Input
import numpy as np

# ✅ 모델 재구성 (명시적 입력 추가)
input_layer = Input(shape=(112, 112, 3))
x = layers.Conv2D(128, (3,3), activation='relu')(input_layer)
x = layers.BatchNormalization(name='batch_normalization')(x)
x = layers.Dropout(0.7)(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.7)(x)
output_layer = layers.Dense(1, activation='sigmoid')(x)

# ✅ 모델 컴파일
model_rgb = models.Model(inputs=input_layer, outputs=output_layer)
model_rgb.compile(optimizer='adam', loss='binary_crossentropy')

# ✅ 모델을 호출하여 입력 정의
sample_image = x_train_rgb[0:1]  
_ = model_rgb.predict(sample_image)  # 입력을 한 번 호출하여 정의

# ✅ BatchNormalization 이후의 출력을 추출하는 중간 모델 생성
intermediate_model_bn = models.Model(inputs=model_rgb.input, 
                                     outputs=model_rgb.get_layer('batch_normalization').output)

# ✅ BatchNormalization 전후 데이터 수집
original_output = sample_image.flatten()  # 원본 데이터
bn_output = intermediate_model_bn.predict(sample_image).flatten()  # BatchNormalization 적용 후

# ✅ 시각화: BatchNormalization 전/후 비교
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(original_output, bins=50, alpha=0.7, color='blue')
plt.title('Before BatchNormalization')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(bn_output, bins=50, alpha=0.7, color='green')
plt.title('After BatchNormalization')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
