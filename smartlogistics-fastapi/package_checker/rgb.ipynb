# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 이미지 데이터 경로
image_dir = r"output_image/box_damaged_1412"

# 데이터 저장 리스트 초기화
red_channel = []
green_channel = []
blue_channel = []

# 이미지 로딩 및 RGB 분리
for filename in os.listdir(image_dir):
    if filename.lower().endswith(('.jpg', '.png', '.jpeg', '.png')):
        image_path = os.path.join(image_dir, filename)
        try:
            # ✅ 이미지 로딩 (RGBA 변환 포함)
            with Image.open(image_path) as img:
                if img.mode != 'RGB':
                    img = img.convert('RGB')
                
                # ✅ 데이터 추가를 덮어쓰기로 변경
                img_array = np.array(img)
                
                red_channel = img_array[:, :, 0].flatten()
                green_channel = img_array[:, :, 1].flatten()
                blue_channel = img_array[:, :, 2].flatten()
                
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# ✅ 각 채널 총합 및 평균 계산
red_sum = np.sum(red_channel)
green_sum = np.sum(green_channel)
blue_sum = np.sum(blue_channel)

print(f"Red Channel - Total: {red_sum}, Mean: {np.mean(red_channel)}")
print(f"Green Channel - Total: {green_sum}, Mean: {np.mean(green_channel)}")
print(f"Blue Channel - Total: {blue_sum}, Mean: {np.mean(blue_channel)}")

# ✅ 픽셀 값 총합 그래프
plt.figure(figsize=(8, 6))
plt.bar(['Red', 'Green', 'Blue'], [red_sum, green_sum, blue_sum], color=['red', 'green', 'blue'])
plt.title('RGB Total Pixel Value Comparison')
plt.xlabel('Color Channel')
plt.ylabel('Sum of Pixel Values')
plt.tight_layout()
plt.show()
# Out:
# Red Channel - Total: 2096416, Mean: 87.40529497602668
# Green Channel - Total: 1763602, Mean: 73.52937252449448
# Blue Channel - Total: 1449038, Mean: 60.41434229726913

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 이미지 데이터 경로
image_dir = r"output_image/total_image"

# 데이터 저장 리스트 초기화
red_channel = []
green_channel = []
blue_channel = []

# 이미지 로딩 및 RGB 분리
for filename in os.listdir(image_dir):
    if filename.lower().endswith(('.jpg', '.png', '.jpeg', '.png')):
        image_path = os.path.join(image_dir, filename)
        try:
            # ✅ 이미지 로딩 (RGBA 변환 포함)
            with Image.open(image_path) as img:
                if img.mode != 'RGB':
                    img = img.convert('RGB')
                
                # ✅ 데이터 추가를 덮어쓰기로 변경
                img_array = np.array(img)
                
                red_channel = img_array[:, :, 0].flatten()
                green_channel = img_array[:, :, 1].flatten()
                blue_channel = img_array[:, :, 2].flatten()
                
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# ✅ 각 채널 총합 및 평균 계산
red_sum = np.sum(red_channel)
green_sum = np.sum(green_channel)
blue_sum = np.sum(blue_channel)

print(f"Red Channel - Total: {red_sum}, Mean: {np.mean(red_channel)}")
print(f"Green Channel - Total: {green_sum}, Mean: {np.mean(green_channel)}")
print(f"Blue Channel - Total: {blue_sum}, Mean: {np.mean(blue_channel)}")

# ✅ 픽셀 값 총합 그래프
plt.figure(figsize=(8, 6))
plt.bar(['Red', 'Green', 'Blue'], [red_sum, green_sum, blue_sum], color=['lightcoral', 'lightgreen', 'lightblue'])
plt.title('RGB Total Pixel Value Comparison')
plt.xlabel('Color Channel')
plt.ylabel('Sum of Pixel Values')
plt.tight_layout()
plt.show()
# Out:
# Red Channel - Total: 188715, Mean: 93.60863095238095
# Green Channel - Total: 164296, Mean: 81.49603174603175
# Blue Channel - Total: 164226, Mean: 81.46130952380952

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 이미지 데이터 경로
image_dir = r"output_image/total_image"

# 데이터 저장 리스트 초기화
red_channel_total = []
green_channel_total = []
blue_channel_total = []

# 원하는 이미지 크기 지정 (예: 224x224)
desired_width = 224
desired_height = 224

# 이미지 로딩 및 RGB 분리
for filename in os.listdir(image_dir):
    if filename.lower().endswith(('.jpg', '.png', '.jpeg', '.png')):  # 확장자 확인
        image_path = os.path.join(image_dir, filename)
        try:
            # 이미지 로딩 (RGBA 변환 포함)
            with Image.open(image_path) as img:
                if img.mode != 'RGB':
                    img = img.convert('RGB')

                # 이미지 크기 리사이즈
                img = img.resize((desired_width, desired_height))

                # 이미지에서 채널 값 추출
                img_array = np.array(img)
                red_channel_total.append(img_array[:, :, 0].flatten())  # 빨간색 채널
                green_channel_total.append(img_array[:, :, 1].flatten())  # 초록색 채널
                blue_channel_total.append(img_array[:, :, 2].flatten())  # 파란색 채널
                
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# 배열이 2D 형태로 합쳐질 수 있도록 변경
red_channel_total = np.array(red_channel_total)
green_channel_total = np.array(green_channel_total)
blue_channel_total = np.array(blue_channel_total)

# 각 채널의 총합 및 평균 계산
red_sum_total = np.sum(red_channel_total)
green_sum_total = np.sum(green_channel_total)
blue_sum_total = np.sum(blue_channel_total)

print(f"Red Channel - Total: {red_sum_total}, Mean: {np.mean(red_channel_total)}")
print(f"Green Channel - Total: {green_sum_total}, Mean: {np.mean(green_channel_total)}")
print(f"Blue Channel - Total: {blue_sum_total}, Mean: {np.mean(blue_channel_total)}")

# 픽셀 값 총합 그래프
plt.figure(figsize=(8, 6))
plt.bar(['Red', 'Green', 'Blue'], [red_sum_total, green_sum_total, blue_sum_total], color=['red', 'green', 'blue'])
plt.title('RGB Total Pixel Value Comparison')
plt.xlabel('Color Channel')
plt.ylabel('Sum of Pixel Values')
plt.tight_layout()
plt.show()
# Out:
# Red Channel - Total: 2479394753, Mean: 141.29322798175235
# Green Channel - Total: 3942011297, Mean: 120.93682085435034
# Blue Channel - Total: 1296081993, Mean: 101.92024456890469

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 이미지 데이터 경로
image_dir = r"output_image/box_normal_1361"

# 데이터 저장 리스트 초기화
red_channel_total = []
green_channel_total = []
blue_channel_total = []

# 원하는 이미지 크기 지정 (예: 224x224)
desired_width = 224
desired_height = 224

# 이미지 로딩 및 RGB 분리
for filename in os.listdir(image_dir):
    if filename.lower().endswith(('.jpg', '.png', '.jpeg', '.png')):  # 확장자 확인
        image_path = os.path.join(image_dir, filename)
        try:
            # 이미지 로딩 (RGBA 변환 포함)
            with Image.open(image_path) as img:
                if img.mode != 'RGB':
                    img = img.convert('RGB')

                # 이미지 크기 리사이즈
                img = img.resize((desired_width, desired_height))

                # 이미지에서 채널 값 추출
                img_array = np.array(img)
                red_channel_total.append(img_array[:, :, 0].flatten())  # 빨간색 채널
                green_channel_total.append(img_array[:, :, 1].flatten())  # 초록색 채널
                blue_channel_total.append(img_array[:, :, 2].flatten())  # 파란색 채널
                
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# 배열이 2D 형태로 합쳐질 수 있도록 변경
red_channel_total = np.array(red_channel_total)
green_channel_total = np.array(green_channel_total)
blue_channel_total = np.array(blue_channel_total)

# 각 채널의 총합 및 평균 계산
red_sum_total = np.sum(red_channel_total)
green_sum_total = np.sum(green_channel_total)
blue_sum_total = np.sum(blue_channel_total)

print(f"Red Channel - Total: {red_sum_total}, Mean: {np.mean(red_channel_total)}")
print(f"Green Channel - Total: {green_sum_total}, Mean: {np.mean(green_channel_total)}")
print(f"Blue Channel - Total: {blue_sum_total}, Mean: {np.mean(blue_channel_total)}")

# 픽셀 값 총합 그래프
plt.figure(figsize=(8, 6))
plt.bar(['Red', 'Green', 'Blue'], [red_sum_total, green_sum_total, blue_sum_total], color=['red', 'green', 'blue'])
plt.title('RGB Total Pixel Value Comparison')
plt.xlabel('Color Channel')
plt.ylabel('Sum of Pixel Values')
plt.tight_layout()
plt.show()
# Out:
# Red Channel - Total: 1397070609, Mean: 146.2450294141697
# Green Channel - Total: 4272220938, Mean: 125.45389434187985
# Blue Channel - Total: 2978569348, Mean: 106.5102659944856

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 이미지 데이터 경로
image_dir = r"output_image/box_normal_1361"

# 데이터 저장 리스트 초기화
red_channel = []
green_channel = []
blue_channel = []

# 이미지 로딩 및 RGB 분리
for filename in os.listdir(image_dir):
    if filename.lower().endswith(('.jpg', '.png', '.jpeg', '.png')):
        image_path = os.path.join(image_dir, filename)
        try:
            # 이미지 로딩 (RGBA 변환 포함)
            with Image.open(image_path) as img:
                if img.mode != 'RGB':
                    img = img.convert('RGB')
                
                # 채널 값 누적
                img_array = np.array(img)
                
                red_channel.extend(img_array[:, :, 0].flatten())  # Red 채널 값 누적
                green_channel.extend(img_array[:, :, 1].flatten())  # Green 채널 값 누적
                blue_channel.extend(img_array[:, :, 2].flatten())  # Blue 채널 값 누적
                
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# 각 채널 총합 및 평균 계산
red_sum = np.sum(red_channel)
green_sum = np.sum(green_channel)
blue_sum = np.sum(blue_channel)

print(f"Red Channel - Total: {red_sum}, Mean: {np.mean(red_channel)}")
print(f"Green Channel - Total: {green_sum}, Mean: {np.mean(green_channel)}")
print(f"Blue Channel - Total: {blue_sum}, Mean: {np.mean(blue_channel)}")

# 픽셀 값 총합 그래프
plt.figure(figsize=(8, 6))
plt.bar(['Red', 'Green', 'Blue'], [red_sum, green_sum, blue_sum], color=['red', 'green', 'blue'])
plt.title('RGB Total Pixel Value Comparison')
plt.xlabel('Color Channel')
plt.ylabel('Sum of Pixel Values')
plt.tight_layout()
plt.show()
# Out:
# Red Channel - Total: 3291296441, Mean: 174.07263159091497
# Green Channel - Total: 2136377522, Mean: 157.15184493622584
# Blue Channel - Total: 894088831, Mean: 138.95099848880173

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 이미지 데이터 경로
image_dir = r"output_image/total_image"

# 데이터 저장 리스트 초기화
red_channel = []
green_channel = []
blue_channel = []

# 이미지 로딩 및 RGB 분리
for filename in os.listdir(image_dir):
    if filename.lower().endswith(('.jpg', '.png', '.jpeg', '.png')):
        image_path = os.path.join(image_dir, filename)
        try:
            # 이미지 로딩 (RGBA 변환 포함)
            with Image.open(image_path) as img:
                if img.mode != 'RGB':
                    img = img.convert('RGB')
                
                # 채널 값 누적
                img_array = np.array(img)
                
                red_channel.extend(img_array[:, :, 0].flatten())  # Red 채널 값 누적
                green_channel.extend(img_array[:, :, 1].flatten())  # Green 채널 값 누적
                blue_channel.extend(img_array[:, :, 2].flatten())  # Blue 채널 값 누적
                
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# 각 채널 총합 및 평균 계산
red_sum = np.sum(red_channel)
green_sum = np.sum(green_channel)
blue_sum = np.sum(blue_channel)

print(f"Red Channel - Total: {red_sum}, Mean: {np.mean(red_channel)}")
print(f"Green Channel - Total: {green_sum}, Mean: {np.mean(green_channel)}")
print(f"Blue Channel - Total: {blue_sum}, Mean: {np.mean(blue_channel)}")

# 픽셀 값 총합 그래프
plt.figure(figsize=(8, 6))
plt.bar(['Red', 'Green', 'Blue'], [red_sum, green_sum, blue_sum], color=['red', 'green', 'blue'])
plt.title('RGB Total Pixel Value Comparison')
plt.xlabel('Color Channel')
plt.ylabel('Sum of Pixel Values')
plt.tight_layout()
plt.show()
# Out:
# Error processing image_normal_1191.jpg:
# Error processing image_normal_1193.jpg:
# Error processing rembg_image_damaged_0001.jpg:
# Error processing rembg_image_damaged_0008.jpg:
# Error processing rembg_image_damaged_0009.jpg:
# Error processing rembg_image_damaged_0010.jpg:
# Error processing rembg_image_damaged_0011.jpg:
# Error processing rembg_image_damaged_0012.jpg:
# Error processing rembg_image_damaged_0013.jpg:
# Error processing rembg_image_damaged_0014.jpg:
# Error processing rembg_image_damaged_0015.jpg:
# Error processing rembg_image_damaged_0016.jpg:
# Error processing rembg_image_damaged_0017.jpg:
# Error processing rembg_image_damaged_0018.jpg:
# Error processing rembg_image_damaged_0020.jpg:
# Error processing rembg_image_damaged_0021.jpg:
# Error processing rembg_image_damaged_0022.jpg:
# Error processing rembg_image_damaged_0023.jpg:
# Error processing rembg_image_damaged_0025.jpg:
# Error processing rembg_image_damaged_0026.jpg:
# Error processing rembg_image_damaged_0027.jpg:
# Error processing rembg_image_damaged_0028.jpg:
# Error processing rembg_image_damaged_0029.jpg:
# Error processing rembg_image_damaged_0030.jpg:
# Error processing rembg_image_damaged_0032.jpg:
# Error processing rembg_image_damaged_0034.jpg:
# Error processing rembg_image_damaged_0036.jpg:
# Error processing rembg_image_damaged_0037.jpg:
# Error processing rembg_image_damaged_0038.jpg:
# Error processing rembg_image_damaged_0039.jpg:
# Error processing rembg_image_damaged_0040.jpg:
# Error processing rembg_image_damaged_0041.jpg:
# Error processing rembg_image_damaged_0043.jpg:
# Error processing rembg_image_damaged_0044.jpg:
# Error processing rembg_image_damaged_0045.jpg:
# Error processing rembg_image_normal_0145.jpg:
# Error processing rembg_image_normal_0146.jpg:
# Error processing rembg_image_normal_0148.jpg:
# Error processing rembg_image_normal_0152.jpg:
# Error processing rembg_image_normal_0154.jpg:
# Error processing rembg_image_normal_0161.jpg:
# Error processing rembg_image_normal_0162.jpg:
# Error processing rembg_image_normal_0163.jpg:
# Error processing rembg_image_normal_0165.jpg:
# Error processing rembg_image_normal_0168.jpg:
# Error processing rembg_image_normal_0170.jpg:
# Error processing rembg_image_normal_0171.jpg:
# Error processing rembg_image_normal_0173.jpg:
# Error processing rembg_image_normal_0175.jpg:
# Error processing rembg_image_normal_0176.jpg:
# Error processing rembg_image_normal_0177.jpg:
# Error processing rembg_image_normal_0179.jpg:
# Error processing rembg_image_normal_0182.jpg:
# Error processing rembg_image_normal_0184.jpg:
# Error processing rembg_image_normal_0192.jpg:
# Error processing rembg_image_normal_0193.jpg:
# Error processing rembg_image_normal_0194.jpg:
# Error processing rembg_image_normal_0195.jpg:
# Error processing rembg_image_normal_0196.jpg:
# Error processing rembg_image_normal_0197.jpg:
# Error processing rembg_image_normal_0198.jpg:
# Error processing rembg_image_normal_0204.jpg:
# Error processing rembg_image_normal_0227.jpg:
# Error processing rembg_image_normal_0228.jpg:
# Error processing rembg_image_normal_0240.jpg:
# Error processing rembg_image_normal_0242.jpg:
# Error processing rembg_image_normal_0263.jpg:
# Error processing rembg_image_normal_0266.jpg:
# Error processing rembg_image_normal_0268.jpg:
# Error processing rembg_image_normal_0269.jpg:
# Error processing rembg_image_normal_0270.jpg:
# Error processing rembg_image_normal_0275.jpg:
# Error processing rembg_image_normal_0276.jpg:
# Error processing rembg_image_normal_0278.jpg:
# Error processing rembg_image_normal_0280.jpg:
# Error processing rembg_image_normal_0281.jpg:
# Error processing rembg_image_normal_0282.jpg:
# Error processing rembg_image_normal_0286.jpg:
# Error processing rembg_image_normal_0287.jpg:
# Error processing rembg_image_normal_0288.jpg:
# Error processing rembg_image_normal_0291.jpg:
# Error processing rembg_image_normal_0292.jpg:
# Error processing rembg_image_normal_0293.jpg:
# Error processing rembg_image_normal_0294.jpg:
# Error processing rembg_image_normal_0295.jpg:
# Error processing rembg_image_normal_0296.jpg:
# Error processing rembg_image_normal_0297.jpg:
# Error processing rembg_image_normal_0298.jpg:
# Error processing rembg_image_normal_0305.jpg:
# Error processing rembg_image_normal_0307.jpg:
# Error processing rembg_image_normal_0310.jpg:
# Error processing rembg_image_normal_0313.jpg:
# Error processing rembg_image_normal_0314.jpg:
# Error processing rembg_image_normal_0315.jpg:
# Error processing rembg_image_normal_0316.jpg:
# Error processing rembg_image_normal_0326.jpg:
# Error processing rembg_image_normal_0327.jpg:
# Error processing rembg_image_normal_0329.jpg:
# Error processing rembg_image_normal_0330.jpg:
# Error processing rembg_image_normal_0331.jpg:
# Error processing rembg_image_normal_0337.jpg:
# Error processing rembg_image_normal_0349.jpg:
# Error processing rembg_image_normal_0350.jpg:
# Error processing rembg_image_normal_0353.jpg:
# Error processing rembg_image_normal_0358.jpg:
# Error processing rembg_image_normal_0361.jpg:
# Error processing rembg_image_normal_0364.jpg:
# Error processing rembg_image_normal_0365.jpg:
# Error processing rembg_image_normal_0367.jpg:
# Error processing rembg_image_normal_0370.jpg:
# Error processing rembg_image_normal_0371.jpg:
# Error processing rembg_image_normal_0376.jpg:
# Error processing rembg_image_normal_0380.jpg:
# Error processing rembg_image_normal_0384.jpg:
# Error processing rembg_image_normal_0385.jpg:
# Error processing rembg_image_normal_0386.jpg:
# Error processing rembg_image_normal_0388.jpg:
# Error processing rembg_image_normal_0390.jpg:
# Error processing rembg_image_normal_0393.jpg:
# Error processing rembg_image_normal_0397.jpg:
# Error processing rembg_image_normal_0398.jpg:
# Error processing rembg_image_normal_0399.jpg:
# Error processing rembg_image_normal_0401.jpg:
# Error processing rembg_image_normal_0402.jpg:
# Error processing rembg_image_normal_0407.jpg:
# Error processing rembg_image_normal_0412.jpg:
# Error processing rembg_image_normal_0414.jpg:
# Error processing rembg_image_normal_0415.jpg:
# Error processing rembg_image_normal_0416.jpg:
# Error processing rembg_image_normal_0417.jpg:
# Error processing rembg_image_normal_0418.jpg:
# Error processing rembg_image_normal_0420.jpg:
# Error processing rembg_image_normal_0431.jpg:
# Error processing rembg_image_normal_0434.jpg:
# Error processing rembg_image_normal_0441.jpg:
# Error processing rembg_image_normal_0445.jpg:
# Error processing rembg_image_normal_0446.jpg:
# Error processing rembg_image_normal_0447.jpg:
# Error processing rembg_image_normal_0448.jpg:
# Error processing rembg_image_normal_0449.jpg:
# Error processing rembg_image_normal_0450.jpg:
# Error processing rembg_image_normal_0454.jpg:
# Error processing rembg_image_normal_0458.jpg:
# Error processing rembg_image_normal_0463.jpg:
# Error processing rembg_image_normal_0472.jpg:
# Error processing rembg_image_normal_0474.jpg:
# Error processing rembg_image_normal_0475.jpg:
# Error processing rembg_image_normal_0476.jpg:
# Error processing rembg_image_normal_0477.jpg:
# Error processing rembg_image_normal_0478.jpg:
# Error processing rembg_image_normal_0479.jpg:
# Error processing rembg_image_normal_0488.jpg:
# Error processing rembg_image_normal_0489.jpg:
# Error processing rembg_image_normal_0491.jpg:
# Error processing rembg_image_normal_0492.jpg:
# Error processing rembg_image_normal_0493.jpg:
# Error processing rembg_image_normal_0497.jpg:
# Error processing rembg_image_normal_0512.jpg:
# Error processing rembg_image_normal_0513.jpg:
# Error processing rembg_image_normal_0514.jpg:
# Error processing rembg_image_normal_0515.jpg:
# Error processing rembg_image_normal_0516.jpg:
# Error processing rembg_image_normal_0517.jpg:
# Error processing rembg_image_normal_0518.jpg:
# Error processing rembg_image_normal_0520.jpg:
# Error processing rembg_image_normal_0521.jpg:
# Error processing rembg_image_normal_0522.jpg:
# Error processing rembg_image_normal_0524.jpg:
# Error processing rembg_image_normal_0526.jpg:
# Error processing rembg_image_normal_0527.jpg:
# Error processing rembg_image_normal_0529.jpg:
# Error processing rembg_image_normal_0531.jpg:
# Error processing rembg_image_normal_0532.jpg:
# Error processing rembg_image_normal_0533.jpg:
# Error processing rembg_image_normal_0534.jpg:
# Error processing rembg_image_normal_0537.jpg:
# Error processing rembg_image_normal_0538.jpg:
# Error processing rembg_image_normal_0541.jpg:
# Error processing rembg_image_normal_0542.jpg:
# Error processing rembg_image_normal_0547.jpg:
# Error processing rembg_image_normal_0548.jpg:
# Error processing rembg_image_normal_0550.jpg:
# Error processing rembg_image_normal_0555.jpg:
# Error processing rembg_image_normal_0557.jpg:
# Error processing rembg_image_normal_0558.jpg:
# Error processing rembg_image_normal_0560.jpg:
# Error processing rembg_image_normal_0561.jpg:
# Error processing rembg_image_normal_0573.jpg:
# Error processing rembg_image_normal_0574.jpg:
# Error processing rembg_image_normal_0575.jpg:
# Error processing rembg_image_normal_0576.jpg:
# Error processing rembg_image_normal_0578.jpg:
# Error processing rembg_image_normal_0579.jpg:
# Error processing rembg_image_normal_0582.jpg:
# Error processing rembg_image_normal_0593.jpg:
# Error processing rembg_image_normal_0594.jpg:
# Error processing rembg_image_normal_0595.jpg:
# Error processing rembg_image_normal_0596.jpg:
# Error processing rembg_image_normal_0597.jpg:
# Error processing rembg_image_normal_0598.jpg:
# Error processing rembg_image_normal_0600.jpg:
# Error processing rembg_image_normal_0601.jpg:
# Error processing rembg_image_normal_0602.jpg:
# Error processing rembg_image_normal_0603.jpg:
# Error processing rembg_image_normal_0604.jpg:
# Error processing rembg_image_normal_0605.jpg:
# Error processing rembg_image_normal_0607.jpg:
# Error processing rembg_image_normal_0608.jpg:
# Error processing rembg_image_normal_0609.jpg:
# Error processing rembg_image_normal_0610.jpg:
# Error processing rembg_image_normal_0612.jpg:
# Error processing rembg_image_normal_0613.jpg:
# Error processing rembg_image_normal_0614.jpg:
# Error processing rembg_image_normal_0615.jpg:
# Error processing rembg_image_normal_0617.jpg:
# Error processing rembg_image_normal_0618.jpg:
# Error processing rembg_image_normal_0620.jpg:
# Error processing rembg_image_normal_0621.jpg:
# Error processing rembg_image_normal_0622.jpg:
# Error processing rembg_image_normal_0623.jpg:
# Error processing rembg_image_normal_0624.jpg:
# Error processing rembg_image_normal_0625.jpg:
# Error processing rembg_image_normal_0626.jpg:
# Error processing rembg_image_normal_0627.jpg:
# Error processing rembg_image_normal_0628.jpg:
# Error processing rembg_image_normal_0629.jpg:
# Error processing rembg_image_normal_0631.jpg:
# Error processing rembg_image_normal_0632.jpg:
# Error processing rembg_image_normal_0633.jpg:
# Error processing rembg_image_normal_0634.jpg:
# Error processing rembg_image_normal_0636.jpg:
# Error processing rembg_image_normal_0637.jpg:
# Error processing rembg_image_normal_0638.jpg:
# Error processing rembg_image_normal_0639.jpg:
# Error processing rembg_image_normal_0643.jpg:
# Error processing rembg_image_normal_0644.jpg:
# Error processing rembg_image_normal_0645.jpg:
# Error processing rembg_image_normal_0646.jpg:
# Error processing rembg_image_normal_0647.jpg:
# Error processing rembg_image_normal_0648.jpg:
# Error processing rembg_image_normal_0649.jpg:
# Error processing rembg_image_normal_0650.jpg:
# Error processing rembg_image_normal_0651.jpg:
# Error processing rembg_image_normal_0652.jpg:
# Error processing rembg_image_normal_0653.jpg:
# Error processing rembg_image_normal_0654.jpg:
# Error processing rembg_image_normal_0655.jpg:
# Error processing rembg_image_normal_0656.jpg:
# Error processing rembg_image_normal_0657.jpg:
# Error processing rembg_image_normal_0658.jpg:
# Error processing rembg_image_normal_0659.jpg:
# Error processing rembg_image_normal_0660.jpg:
# Error processing rembg_image_normal_0662.jpg:
# Error processing rembg_image_normal_0663.jpg:
# Error processing rembg_image_normal_0664.jpg:
# Error processing rembg_image_normal_0666.jpg:
# Error processing rembg_image_normal_0668.jpg:
# Error processing rembg_image_normal_0669.jpg:
# Error processing rembg_image_normal_0671.jpg:
# Error processing rembg_image_normal_0672.jpg:
# Error processing rembg_image_normal_0673.jpg:
# Error processing rembg_image_normal_0674.jpg:
# Error processing rembg_image_normal_0675.jpg:
# Error processing rembg_image_normal_0676.jpg:
# Error processing rembg_image_normal_0677.jpg:
# Error processing rembg_image_normal_0678.jpg:
# Error processing rembg_image_normal_0679.jpg:
# Error processing rembg_image_normal_0699.jpg:
# Error processing rembg_image_normal_0701.jpg:
# Error processing rembg_image_normal_0731.jpg:
# Error processing rembg_image_normal_0732.jpg:
# Error processing rembg_image_normal_0733.jpg:
# Error processing rembg_image_normal_0734.jpg:
# Error processing rembg_image_normal_0735.jpg:
# Error processing rembg_image_normal_0736.jpg:
# Error processing rembg_image_normal_0738.jpg:
# Error processing rembg_image_normal_0743.jpg:
# Error processing rembg_image_normal_0747.jpg:
# Error processing rembg_image_normal_0762.jpg:
# Error processing rembg_image_normal_0765.jpg:
# Error processing rembg_image_normal_0767.jpg:
# Error processing rembg_image_normal_0768.jpg:
# Error processing rembg_image_normal_0769.jpg:
# Error processing rembg_image_normal_0772.jpg:
# Error processing rembg_image_normal_0776.jpg:
# Error processing rembg_image_normal_0777.jpg:
# Error processing rembg_image_normal_0778.jpg:
# Error processing rembg_image_normal_0779.jpg:
# Error processing rembg_image_normal_0782.jpg:
# Error processing rembg_image_normal_0792.jpg:
# Error processing rembg_image_normal_0793.jpg:
# Error processing rembg_image_normal_0794.jpg:
# Error processing rembg_image_normal_0796.jpg:
# Error processing rembg_image_normal_0797.jpg:
# Error processing rembg_image_normal_0798.jpg:
# Error processing rembg_image_normal_0848.jpg:
# Error processing rembg_image_normal_0854.jpg:
# Error processing rembg_image_normal_0868.jpg:
# Error processing rembg_image_normal_0881.jpg:
# Error processing rembg_image_normal_0883.jpg:
# Error processing rembg_image_normal_0885.jpg:
# Error processing rembg_image_normal_0886.jpg:
# Error processing rembg_image_normal_0891.jpg:
# Error processing rembg_image_normal_0892.jpg:
# Error processing rembg_image_normal_0894.jpg:
# Error processing rembg_image_normal_0895.jpg:
# Error processing rembg_image_normal_0896.jpg:
# Error processing rembg_image_normal_0897.jpg:
# Error processing rembg_image_normal_0898.jpg:
# Error processing rembg_image_normal_0904.jpg:
# Error processing rembg_image_normal_0905.jpg:
# Error processing rembg_image_normal_0906.jpg:
# Error processing rembg_image_normal_0907.jpg:
# Error processing rembg_image_normal_0908.jpg:
# Error processing rembg_image_normal_0909.jpg:
# Error processing rembg_image_normal_0910.jpg:
# Error processing rembg_image_normal_0911.jpg:
# Error processing rembg_image_normal_0912.jpg:
# Error processing rembg_image_normal_0913.jpg:
# Error processing rembg_image_normal_0915.jpg:
# Error processing rembg_image_normal_0916.jpg:
# Error processing rembg_image_normal_0917.jpg:
# Error processing rembg_image_normal_0918.jpg:
# Error processing rembg_image_normal_0919.jpg:
# Error processing rembg_image_normal_0920.jpg:
# Error processing rembg_image_normal_0923.jpg:
# Error processing rembg_image_normal_0924.jpg:
# Error processing rembg_image_normal_0925.jpg:
# Error processing rembg_image_normal_0926.jpg:
# Error processing rembg_image_normal_0927.jpg:
# Error processing rembg_image_normal_0928.jpg:
# Error processing rembg_image_normal_0929.jpg:
# Error processing rembg_image_normal_0931.jpg:
# Error processing rembg_image_normal_0932.jpg:
# Error processing rembg_image_normal_0933.jpg:
# Error processing rembg_image_normal_0934.jpg:
# Error processing rembg_image_normal_0941.jpg:
# Error processing rembg_image_normal_0942.jpg:
# Error processing rembg_image_normal_0944.jpg:
# Error processing rembg_image_normal_0945.jpg:
# Error processing rembg_image_normal_0946.jpg:
# Error processing rembg_image_normal_0947.jpg:
# Error processing rembg_image_normal_0948.jpg:
# Error processing rembg_image_normal_0949.jpg:
# Error processing rembg_image_normal_0951.jpg:
# Error processing rembg_image_normal_0952.jpg:
# Error processing rembg_image_normal_0953.jpg:
# Error processing rembg_image_normal_0954.jpg:
# Error processing rembg_image_normal_0955.jpg:
# Error processing rembg_image_normal_0957.jpg:
# Error processing rembg_image_normal_0958.jpg:
# Error processing rembg_image_normal_0959.jpg:
# Error processing rembg_image_normal_0962.jpg:
# Error processing rembg_image_normal_0963.jpg:
# Error processing rembg_image_normal_0964.jpg:
# Error processing rembg_image_normal_0965.jpg:
# Error processing rembg_image_normal_0966.jpg:
# Error processing rembg_image_normal_0967.jpg:
# Error processing rembg_image_normal_0968.jpg:
# Error processing rembg_image_normal_0970.jpg:
# Error processing rembg_image_normal_0973.jpg:
# Error processing rembg_image_normal_0975.jpg:
# Error processing rembg_image_normal_0981.jpg:
# Error processing rembg_image_normal_0989.jpg:
# Error processing rembg_image_normal_0990.jpg:
# Error processing rembg_image_normal_0991.jpg:
# Error processing rembg_image_normal_0992.jpg:
# Error processing rembg_image_normal_0994.jpg:
# Error processing rembg_image_normal_0995.jpg:
# Error processing rembg_image_normal_0996.jpg:
# Error processing rembg_image_normal_0997.jpg:
# Error processing rembg_image_normal_0998.jpg:
# Error processing rembg_image_normal_1000.jpg:
# Error processing rembg_image_normal_1001.jpg:
# Error processing rembg_image_normal_1002.jpg:
# Error processing rembg_image_normal_1004.jpg:
# Error processing rembg_image_normal_1009.jpg:
# Error processing rembg_image_normal_1010.jpg:
# Error processing rembg_image_normal_1011.jpg:
# Error processing rembg_image_normal_1012.jpg:
# Error processing rembg_image_normal_1013.jpg:
# Error processing rembg_image_normal_1014.jpg:
# Error processing rembg_image_normal_1015.jpg:
# Error processing rembg_image_normal_1017.jpg:
# Error processing rembg_image_normal_1018.jpg:
# Error processing rembg_image_normal_1130.jpg:
# Error processing rembg_image_normal_1131.jpg:
# Error processing rembg_image_normal_1133.jpg:
# Error processing rembg_image_normal_1134.jpg:
# Error processing rembg_image_normal_1140.jpg:
# Error processing rembg_image_normal_1142.jpg:
# Error processing rembg_image_normal_1148.jpg:
# Error processing rembg_image_normal_1149.jpg:
# Error processing rembg_image_normal_1157.jpg:
# Error processing rembg_image_normal_1158.jpg:
# Error processing rembg_image_normal_1159.jpg:
# Error processing rembg_image_normal_1160.jpg:
# Error processing rembg_image_normal_1161.jpg:
# Error processing rembg_image_normal_1166.jpg:
# Error processing rembg_image_normal_1168.jpg:
# Error processing rembg_image_normal_1169.jpg:
# Error processing rembg_image_normal_1170.jpg:
# Error processing rembg_image_normal_1172.jpg:
# Error processing rembg_image_normal_1173.jpg:
# Error processing rembg_image_normal_1179.jpg:
# Error processing rembg_image_normal_1180.jpg:
# Error processing rembg_image_normal_1182.jpg:
# Error processing rembg_image_normal_1188.jpg:
# Error processing rembg_image_normal_1189.jpg:
# Error processing rembg_image_normal_1190.jpg:
# Error processing rembg_image_normal_1191.jpg:
# Error processing rembg_image_normal_1193.jpg:
# Error processing rembg_image_normal_1194.jpg:
# Red Channel - Total: 1487555337, Mean: 177.7656091408888
# Green Channel - Total: 45080746, Mean: 159.9243750133425
# Blue Channel - Total: 2812694240, Mean: 141.0333131207452

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 이미지 데이터 경로
image_dir = r"output_image/box_damaged_1412"

# 데이터 저장 리스트 초기화
red_channel = []
green_channel = []
blue_channel = []

# 이미지 로딩 및 RGB 분리
for filename in os.listdir(image_dir):
    if filename.lower().endswith(('.jpg', '.png', '.jpeg', '.png')):
        image_path = os.path.join(image_dir, filename)
        try:
            # 이미지 로딩 (RGBA 변환 포함)
            with Image.open(image_path) as img:
                if img.mode != 'RGB':
                    img = img.convert('RGB')
                
                # 채널 값 누적
                img_array = np.array(img)
                
                red_channel.extend(img_array[:, :, 0].flatten())  # Red 채널 값 누적
                green_channel.extend(img_array[:, :, 1].flatten())  # Green 채널 값 누적
                blue_channel.extend(img_array[:, :, 2].flatten())  # Blue 채널 값 누적
                
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# 각 채널 총합 및 평균 계산
red_sum = np.sum(red_channel)
green_sum = np.sum(green_channel)
blue_sum = np.sum(blue_channel)

print(f"Red Channel - Total: {red_sum}, Mean: {np.mean(red_channel)}")
print(f"Green Channel - Total: {green_sum}, Mean: {np.mean(green_channel)}")
print(f"Blue Channel - Total: {blue_sum}, Mean: {np.mean(blue_channel)}")

# 픽셀 값 총합 그래프
plt.figure(figsize=(8, 6))
plt.bar(['Red', 'Green', 'Blue'], [red_sum, green_sum, blue_sum], color=['red', 'green', 'blue'])
plt.title('RGB Total Pixel Value Comparison')
plt.xlabel('Color Channel')
plt.ylabel('Sum of Pixel Values')
plt.tight_layout()
plt.show()
# Out:
# Red Channel - Total: 827673253, Mean: 132.73268246829323
# Green Channel - Total: 106744762, Mean: 114.05271233122619
# Blue Channel - Total: 3709020439, Mean: 96.10438747147718
